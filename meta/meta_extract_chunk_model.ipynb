# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/
# Out:
# /content

# %% [markdown]
# # 0. 파일 로드

# %%
import os
import json
from tqdm import tqdm  # tqdm 임포트

BASE_DIR = "/content" # 드라이브 주소 수정

# %%
CHUNK_SIZE = 1000
MAX_NEW_TOKENS = 600
CHUNK_OVERLAP = 100 # New: Overlap for text chunking

META_BASE_DIR = os.path.join(BASE_DIR, "meta") # 폴더에 맞게 수정
os.makedirs(META_BASE_DIR, exist_ok=True)

# %%
META_BASE_DIR
# Out:
# '/content/meta'

# %% [markdown]
# # model load

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "Qwen/Qwen3-4B-Instruct-2507"
# model_name = "Qwen/Qwen3-30B-A3B-Instruct-2507"

# load the tokenizer and the model
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="auto",
    device_map="auto"
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/99.6M [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/3.99G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/3.96G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/238 [00:00<?, ?B/s]

# %% [markdown]
# # Prompt

# %%
def generate_prompt(text):
    return f"""
아래 텍스트는 의료 지식 전반(시술, 질환, 영양, 약물, 생리, 예방 등)에 대한 설명입니다.
텍스트의 성격에 맞게 metadata를 JSON으로 생성하세요.

[공통 규칙]
- 시술 관련 내용이 없을 경우, 시술 항목은 빈 배열([])로 두되
  의료 일반 지식에 해당하는 항목은 적극적으로 추출하세요.
- 텍스트에 명확히 등장하지 않는 정보는 추측하지 마세요.
- output으로 metadata만 출력해.

[Metadata 생성 기준]

1. keywords
- 텍스트의 핵심 의료 키워드
- 시술, 질환, 영양소, 약물, 생리 물질, 항산화제, 보충제 등 모두 포함 가능
- 영문, snake_case

2. procedure_type
- 실제 의료 시술, 치료, 처치가 명시된 경우만 추출
- 예: epidural_block, nerve_block, injection, surgery
- 시술이 없으면 []

3. target_area
- 치료 또는 주요 논의 대상이 되는 인체 부위
- 한글 → 영어 표준 용어로 변환
  - 경추 → cervical
  - 흉추 → thoracic
  - 요추 → lumbar
  - 미추/천추 → sacral
- 인체 부위가 아닌 경우 []

4. symptoms
- 환자 증상, 질환의 주요 임상 증상
- 또는 해당 의료 지식이 다루는 건강 문제
- 영문, snake_case
- 증상 개념이 없으면 []

[출력 형식 예시]
{{
  "keywords": ["selenium", "vitamin_e", "antioxidant"],
  "procedure_type": [],
  "target_area": [],
  "symptoms": []
}}

텍스트:
{text}
"""

# %% [markdown]
# ## 병렬처리

# %%
# !rm -rf /content/meta/

# %%
pwd
# Out:
# '/content'

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm

def list_all_chunk_files(chunk_store_dir: str):
    paths = []
    for root, _, files in os.walk(chunk_store_dir):
        for fn in files:
            # done은 제외하고 원본 chunk만 대상
            if "_chunk_" in fn and fn.endswith(".json") and not fn.endswith("_done.json"):
                paths.append(os.path.join(root, fn))
    paths.sort()
    return paths

class ChunkFileDataset(Dataset):
    def __init__(self, chunk_files):
        self.chunk_files = chunk_files

    def __len__(self):
        return len(self.chunk_files)

    def __getitem__(self, idx):
        path = self.chunk_files[idx]

        # 이미 done 파일이 있으면 None 리턴해서 스킵
        done_path = path.replace(".json", "_done.json")
        if os.path.exists(done_path):
            return None

        with open(path, "r", encoding="utf-8") as f:
            item = json.load(f)

        item["_chunk_path"] = path
        item["_done_path"] = done_path
        return item

def collate_keep_valid(batch):
    return [x for x in batch if x is not None]

def safe_json_loads(text: str):
    s = text.strip()
    if s.startswith("```"):
        s = s.strip("`").replace("json", "").strip()
    try:
        return json.loads(s)
    except json.JSONDecodeError:
        s2 = s.replace('"null"', 'null').replace("\\", "")
        try:
            return json.loads(s2)
        except json.JSONDecodeError:
            return None

# %% [markdown]
# ## 강사님

# %%
# !cp -r "/content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/meta/TS_영문_국제기관 가이드라인/" "/content/meta"

# %%
CHUNK_STORE_DIR = "/content/meta/TS_영문_국제기관 가이드라인/drive"

# %%
import os
import json
import re
import torch
from torch.utils.data import DataLoader
from tqdm import tqdm


@torch.inference_mode()
def infer_chunks_to_done_files(chunk_store_dir: str, batch_size: int = 16, MAX_NEW_TOKENS: int = 16):
    chunk_files = list_all_chunk_files(chunk_store_dir)

    ds = ChunkFileDataset(chunk_files)
    dl = DataLoader(
        ds,
        batch_size=batch_size,
        shuffle=False,
        num_workers=0,          # Colab 안정성
        collate_fn=collate_keep_valid
    )

    model.eval()

    processed = 0
    skipped_batches = 0
    parse_fail = 0
    batch_errors = 0

    pattern = re.compile(r"\{[\s\S]*?\}")  # JSON 후보 추출용

    for batch in tqdm(dl, desc="Pass B: 청크 배치 추론 -> done 저장"):
        if len(batch) == 0:
            skipped_batches += 1
            continue

        try:
            # 1) 프롬프트 구성
            texts = []
            for item in batch:
                prompt_text = generate_prompt(item["content"])
                messages = [{"role": "user", "content": prompt_text}]
                text = tokenizer.apply_chat_template(
                    messages,
                    tokenize=False,
                    add_generation_prompt=True,
                )
                texts.append(text)

            # 2) 배치 토크나이즈
            model_inputs = tokenizer(
                texts,
                return_tensors="pt",
                padding=True,
                truncation=True,
            ).to(model.device)

            # 3) 배치 generate
            generated_ids = model.generate(
                **model_inputs,
                max_new_tokens=MAX_NEW_TOKENS,
                do_sample=False
            )

            # generate 정상 여부 1차 검증
            if generated_ids is None or generated_ids.ndim != 2:
                raise RuntimeError("model.generate 결과가 비정상입니다")

            # 4) 디코딩
            decoded_texts = tokenizer.batch_decode(
                generated_ids,
                skip_special_tokens=True
            )

            if len(decoded_texts) != len(batch):
                raise RuntimeError("batch size와 decoded_texts 길이가 불일치합니다")

            # 5) 샘플별 처리
            for item, decoded_text in zip(batch, decoded_texts):
                matches = list(pattern.finditer(decoded_text))

                if len(matches) == 1:
                    parse_fail += 1
                    # print("[JSON 미검출]")
                    # print(decoded_text)
                    # print("-" * 80)
                    continue

                json_candidate = matches[-1].group(0)

                try:
                    obj = json.loads(json_candidate)
                except Exception:
                    parse_fail += 1
                    # print("[JSON 파싱 실패]")
                    # print(decoded_text)
                    # print("-" * 80)
                    continue

                # 6) done 객체 구성
                done_obj = {
                    **item,
                    "chunk_id": item["chunk_id"],
                    "content": item["content"],
                    "keywords": obj.get("keywords", []),
                    "procedure_type": obj.get("procedure_type", []),
                    "target_area": obj.get("target_area", []),
                    "symptoms": obj.get("symptoms", [])
                }

                with open(item["_done_path"], "w", encoding="utf-8") as f:
                    json.dump(done_obj, f, ensure_ascii=False, indent=2)

                processed += 1

        except Exception as e:
            batch_errors += 1
            print("[배치 오류]", str(e))
            continue

    print("\n[Pass B 결과 요약]")
    print("processed done chunks:", processed)
    print("parse_fail chunks:", parse_fail)
    print("batch_errors:", batch_errors)
    if skipped_batches:
        print("skipped empty batches:", skipped_batches)


# 실행
infer_chunks_to_done_files(CHUNK_STORE_DIR, batch_size=100, MAX_NEW_TOKENS = 600)
# Out:
# Pass B: 청크 배치 추론 -> done 저장:   0%|          | 0/40 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:   2%|▎         | 1/40 [02:15<1:28:03, 135.47s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:   5%|▌         | 2/40 [04:25<1:23:51, 132.41s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:   8%|▊         | 3/40 [06:36<1:21:18, 131.85s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  10%|█         | 4/40 [08:54<1:20:21, 133.94s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  12%|█▎        | 5/40 [11:01<1:16:44, 131.55s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  15%|█▌        | 6/40 [13:17<1:15:30, 133.26s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  18%|█▊        | 7/40 [15:27<1:12:42, 132.19s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  20%|██        | 8/40 [17:37<1:10:03, 131.35s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  22%|██▎       | 9/40 [19:52<1:08:30, 132.59s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  25%|██▌       | 10/40 [22:04<1:06:12, 132.42s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  28%|██▊       | 11/40 [24:14<1:03:32, 131.48s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  30%|███       | 12/40 [26:30<1:01:59, 132.85s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  32%|███▎      | 13/40 [28:37<59:00, 131.13s/it]  A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  35%|███▌      | 14/40 [30:45<56:22, 130.08s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  38%|███▊      | 15/40 [32:55<54:16, 130.26s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  40%|████      | 16/40 [35:02<51:37, 129.07s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  42%|████▎     | 17/40 [37:21<50:43, 132.31s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  45%|████▌     | 18/40 [39:44<49:38, 135.38s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  48%|████▊     | 19/40 [42:03<47:46, 136.52s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  50%|█████     | 20/40 [44:17<45:13, 135.66s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  52%|█████▎    | 21/40 [46:38<43:30, 137.41s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  55%|█████▌    | 22/40 [48:54<41:03, 136.86s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  57%|█████▊    | 23/40 [51:13<38:57, 137.49s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  60%|██████    | 24/40 [53:31<36:43, 137.71s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  62%|██████▎   | 25/40 [55:50<34:31, 138.12s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  65%|██████▌   | 26/40 [58:17<32:49, 140.65s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  68%|██████▊   | 27/40 [1:00:38<30:32, 140.94s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  70%|███████   | 28/40 [1:03:02<28:21, 141.75s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  72%|███████▎  | 29/40 [1:05:21<25:49, 140.89s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  75%|███████▌  | 30/40 [1:07:39<23:20, 140.09s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  78%|███████▊  | 31/40 [1:10:10<21:29, 143.30s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  80%|████████  | 32/40 [1:12:28<18:54, 141.75s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  82%|████████▎ | 33/40 [1:14:39<16:10, 138.68s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  85%|████████▌ | 34/40 [1:16:54<13:44, 137.49s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  88%|████████▊ | 35/40 [1:18:59<11:08, 133.70s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  90%|█████████ | 36/40 [1:21:05<08:45, 131.37s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  92%|█████████▎| 37/40 [1:23:13<06:30, 130.26s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  95%|█████████▌| 38/40 [1:25:16<04:16, 128.35s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장:  98%|█████████▊| 39/40 [1:27:24<02:08, 128.05s/it]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Pass B: 청크 배치 추론 -> done 저장: 100%|██████████| 40/40 [1:28:36<00:00, 132.90s/it]
# [Pass B 결과 요약]
# processed done chunks: 2864
# parse_fail chunks: 1087
# batch_errors: 0

# %%
START_TARGET_DIR = "/content/meta/TS_영문_국제기관 가이드라인/drive"

done_count = 0
not_done_cnt = 0

for root, _, files in os.walk(START_TARGET_DIR):
    for fn in files:
        if fn.endswith(".json") and "done" in fn:
            done_count += 1
        not_done_cnt += 1

print(f"done 이 포함된 JSON 파일 개수: {done_count}")
print(f"done 이 포함되지 않은 JSON 파일 개수: {not_done_cnt}")
# Out:
# done 이 포함된 JSON 파일 개수: 653
# done 이 포함되지 않은 JSON 파일 개수: 1405

# %%
# 주소 둘다 바꿔줘야함
os.makedirs("/content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/meta/TS_국문의학 교과서", exist_ok=True)
# !cp -r -v "/content/meta" "/content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/meta/TS_국문의학 교과
json' -> '/content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/meta/TS_국문의학 교과서/meta/cid_1628_1_chunk_002_done.json'
# '/content/meta/cid_1629_1_8292_chunk_000_done.json' -> '/content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/meta/TS_국문의학 교과서/meta/cid_1629_1_8292_chunk_000_done.json'
# '/content/meta/cid_1629_1_8292_chunk_001_done.json' -> '/content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/meta/TS_국문의학 교과서/meta/cid_1629_1_8292_chunk_001_done.json'
# '/content/meta/cid_1629_1_8292_chunk_002_done.json' -> '/content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/meta/TS_국문의학 교과서/meta/cid_1629_1_8292_chunk_002_done.json'
# '/content/meta/cid_1630_1_9742_chunk_000_done.json' -> '/content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/meta/TS_국문의학 교과서/meta/cid_1630_1_9742_chunk_000_done.json'
# '/content/meta/cid_1630_1_9742_chunk_001_done.json' -> '/content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/meta/TS_국문의학 교과서/meta/cid_1630_1_9742_chunk_001_done.json'
# '/content/meta/cid_1630_1_9742_chunk_002_done.json' -> '/content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/meta/TS_국문의학 교과서/meta/cid_1630_1_9742_chunk_002_done.json'
# '/content/meta/cid_1630_1_9742_chunk_003_done.json' -> '/content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/meta/TS_국문의학 교과서/meta/cid_1630_1_9742_chunk_003_done.json'
# '/content/meta/cid_1630_1_9742_chunk_004_done.json' -> '/content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/meta/TS_국문의학 교과서/meta/cid_1630_1_9742_chunk_004_done.json'
# '/content/meta/cid_1630_1_chunk_000_done.json' -> '/content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/meta/TS_국문의학 교과서/meta/cid_1630_1_chunk_000_done.json'
# '/content/meta/cid_1630_1_chunk_001_done.json' -> '/content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/meta/TS_국문의학 교과서/meta/cid_1630_1_chunk_001_done.json'
# '/content/meta/cid_1630_1_chunk_002_done.json' -> '/content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/meta/TS_국문의학 교과서/meta/cid_1630_1_chunk_002_done.json'

# %%
# from google.colab import runtime
# runtime.unassign()

# %%
END_TARGET_DIR = "/content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/meta/TS_국문의학 교과서"

done_count = 0
not_done_cnt = 0
done_files = []

for root, _, filenames in os.walk(END_TARGET_DIR):
    for fn in filenames:
        if not fn.endswith(".json"):
            continue

        if "done" in fn:
            done_count += 1
            if len(done_files) < 10:
                done_files.append(fn)
        else:
            not_done_cnt += 1

print(f"done 이 포함된 JSON 파일 개수: {done_count}")
print(f"done 이 포함되지 않은 JSON 파일 개수: {not_done_cnt}")
# Out:
# done 이 포함된 JSON 파일 개수: 3849
# done 이 포함되지 않은 JSON 파일 개수: 5085

# %%
done_files
# Out:
# ['cid_3815_1_chunk_000_done.json',
#  'cid_3815_1_chunk_001_done.json',
#  'cid_3815_1_chunk_002_done.json',
#  'cid_3816_1_7762_chunk_000_done.json',
#  'cid_3816_1_7762_chunk_001_done.json',
#  'cid_3816_1_7762_chunk_002_done.json',
#  'cid_3816_1_chunk_000_done.json',
#  'cid_3816_1_chunk_001_done.json',
#  'cid_3817_1_4492_chunk_000_done.json',
#  'cid_3817_1_4492_chunk_001_done.json']

# %%
for path in done_file_paths[:10]:  # 너무 많으면 출력이 과도해짐
    print("=" * 80)
    print(f"파일 경로: {path}")

    with open(path, "r", encoding="utf-8") as f:
        raw_text = f.read()

    print(raw_text)
# Out:
# ================================================================================
# 파일 경로: /content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/meta/TS_국문의학 교과서/drive/cid_34782_1_4382_chunk_000_done.json
# {
#   "src_path": "/content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/TS_국문_학술 논문 및 저널/cid_34782_1_4382.json",
#   "ts_folder": "drive",
#   "file_name": "cid_34782_1_4382.json",
#   "base": "cid_34782_1_4382",
#   "chunk_id": 0,
#   "content": "2004년도 보건복지부 지원으로 수행된 \"응급의료 기본계획 수립 및 응급의료 운영체계 평가\" 연구 자료를 기반으로 한 연구입니다. 응급환자의 진료 결과를 향상시키기 위해서는 현장에서 환자의 상태를 정확히 평가하고, 필요한 응급처치를 적시에 적절히 시행하는 것이 중요합니다. 응급구조사 제도 시행 이후 병원 전 단계에서의 응급처치 시행률, 적절성, 의사지도 시행률 등을 평가한 연구들이 보고되었으나, 기존 국내 연구들은 다음과 같은 한계점을 가지고 있었습니다. 첫째, 구급활동일지와 응급실 의무기록 자료의 질적 수준이 낮아 신뢰성 높은 자료를 활용할 필요성이 있었습니다. 둘째, 응급환자의 병원 전 외식 상태 및 생체징후 측정에 대한 평가가 제한적이었습니다. 기존 연구에서는 구급활동일지와 응급실 기록에 기재된 외식 상태의 일치율을 산출하여 평가했으나, 현장에서 병원 전 외식 상태를 측정한 후 병원 도착까지의 시간을 고려하지 못한 한계가 있었습니다. 셋째, 구급인력의 유형에 따른 응급처치 적절성이 평가된 바 없었습니다. 구급인력은 1급 및 2급 응급구조사, 간호사, 기타 인력으로 구분되며, 이들 간의 수행능력 차이가 있다면 이를 바탕으로 정책적 지원이 가능할 것입니다. 넷째, 어떤 지도 의사로부터 의료지도를 받았는지에 대한 연구가 없었습니다. 이 연구는 119 구급대의 병원 전 응급처치 시행률 및 적절성을 측정하고, 구급인력 유형에 따른 응급처치 시행률 및 적절성 차이를 확인하며, 병원 전 응급처치에 필수적인 의료지도 시행 정도와 지도 의사 유형별 의료지도 시행률을 파악하고자 하였습니다. 평가 대상 질환 및 응급처치를 선정하기 위해 문헌 검토와 전문가 합의 방법을 사용하였으며, 미국 캘리포니아주의 1998년 \"응급의료체계의 지속적 질 향상을 위한 표준 및 지침\" 시범사업에서 사용된 평가 지표를 검토하였습니다. 이 지표는 이송 시간 평가, 특정 질환자에 대한 응급처치 시행률 및 성공률, 적절 이송 비율로 구성되어 있습니다. 이를 바탕으로 임상 경력 5년 이상의 응급의학과",
#   "_chunk_path": "/content/meta/TS국문학술 논문 및 저널/drive/cid_34782_1_4382_chunk_000.json",
#   "_done_path": "/content/meta/TS국문학술 논문 및 저널/drive/cid_34782_1_4382_chunk_000_done.json",
#   "keywords": [
#     "emergency_treatment",
#     "emergency_care",
#     "emergency_response",
#     "first_aid",
#     "emergency_assessment",
#     "clinical_outcome",
#     "emergency_medical_system"
#   ],
#   "procedure_type": [],
#   "target_area": [],
#   "symptoms": []
# }
# ================================================================================
# 파일 경로: /content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/meta/TS_국문의학 교과서/drive/cid_34782_1_4382_chunk_002_done.json
# {
#   "src_path": "/content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/TS_국문_학술 논문 및 저널/cid_34782_1_4382.json",
#   "ts_folder": "drive",
#   "file_name": "cid_34782_1_4382.json",
#   "base": "cid_34782_1_4382",
#   "chunk_id": 2,
#   "content": "활성화하고, 1급 응급구조사의 배치를 늘리는 정책적 지원이 필요합니다. 이 연구는 119 구급대의 응급처치 수행 능력을 향상시키기 위한 방안을 마련하는 데 중요한 기초자료를 제공하며, 국내 최초로 다기관 전향적 연구를 통해 응급처치 시행 정도와 적절성을 평가한 점에서 의의가 있습니다.",
#   "_chunk_path": "/content/meta/TS국문학술 논문 및 저널/drive/cid_34782_1_4382_chunk_002.json",
#   "_done_path": "/content/meta/TS국문학술 논문 및 저널/drive/cid_34782_1_4382_chunk_002_done.json",
#   "keywords": [],
#   "procedure_type": [],
#   "target_area": [],
#   "symptoms": []
# }
# ================================================================================
# 파일 경로: /content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/meta/TS_국문의학 교과서/drive/cid_34797_1_chunk_001_done.json
# {
#   "src_path": "/content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/TS_국문_학술 논문 및 저널/cid_34797_1.json",
#   "ts_folder": "drive",
#   "file_name": "cid_34797_1.json",
#   "base": "cid_34797_1",
#   "chunk_id": 1,
#   "content": "수술 적응증으로는 2mm 이상의 안구함몰, 골절면이 안와하벽의 절반 이상을 차지하는 경우, 2주 이상 지속되는 복시 등이 있습니다. 수술은 보통 2주 이내에 시행하는 것이 권장됩니다. 본 연구에서는 복시가 수술 시행 여부를 예측하는 가장 중요한 인자로 나타났으며, 외벽 및 하벽 골절, 두개골 골절 동반도 수술과 연관이 있었습니다. 연구의 제한점으로는 후향적 연구 설계, 단일 기관에서의 연구, 일부 환자의 추적관찰 불가 등이 있었습니다. 결론적으로, 복시를 호소하거나 안구운동장애가 있는 경우, 외벽 및 하벽 골절, 두개골 골절이 동반된 경우 수술 확률이 높으므로, 이러한 환자들에게 적절한 교육과 외래 추적관찰을 통해 적절한 치료를 받을 수 있도록 해야 합니다.",
#   "_chunk_path": "/content/meta/TS국문학술 논문 및 저널/drive/cid_34797_1_chunk_001.json",
#   "_done_path": "/content/meta/TS국문학술 논문 및 저널/drive/cid_34797_1_chunk_001_done.json",
#   "keywords": [
#     "cycloplegia",
#     "diplopia",
#     "orbital_fracture",
#     "surgical_adaptation",
#     "orbital_wall_fracture",
#     "skull_fracture"
#   ],
#   "procedure_type": [
#     "surgery"
#   ],
#   "target_area": [
#     "orbital"
#   ],
#   "symptoms": [
#     "diplopia",
#     "ophthalmoplegia"
#   ]
# }
# ================================================================================
# 파일 경로: /content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/meta/TS_국문의학 교과서/drive/cid_34873_1_0352_chunk_001_done.json
# {
#   "src_path": "/content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/TS_국문_학술 논문 및 저널/cid_34873_1_0352.json",
#   "ts_folder": "drive",
#   "file_name": "cid_34873_1_0352.json",
#   "base": "cid_34873_1_0352",
#   "chunk_id": 1,
#   "content": "정상이었으며 간장이나 비장의 비대 소견도 없었습니다. 직장 수지검사에서 괄약근 긴장도는 정상이었고, 대변 색은 정상적인 갈색이었습니다. 신경학적 검사에서 의식은 혼미 상태였으며, 글래스고우 혼수 척도(GCS)는 10점(E3V2M5)이었습니다. 지남력과 감각은 측정할 수 없었으나, 인형안운동, 동공 반사, 각막 반사 및 안구 운동에는 이상이 없었습니다. 소뇌 기능 검사는 협조되지 않아 시행할 수 없었고, 바빈스키 징후는 관찰되지 않았으며, 심부건 반사는 정상이었습니다. 소변검사에서는 단백질, 당, 케톤, 적혈구, 백혈구가 관찰되지 않았습니다. 심전도와 흉부 방사선 사진에서도 특이 소견은 없었으며, 뇌 전산화 단층촬영에서도 비정상적인 고밀도나 저밀도 음영은 관찰되지 않았습니다. 환자의 혈중 암모니아 수치는 7 mmol/L로 증가하였으며, 이후 혈당은 6시간마다 확인하였으나 150~180 mg/dL 사이에서 유지되었습니다. 치료 후 암모니아 수치는 감소하였고, 환자의 의식도 호전되었습니다. 입원 후 시행한 뇌 영상검사에서도 특이 소견은 없었으며, 혈중 오르니틴, 요중 시스틴, 라신, 호모시트룰린 등의 수치가 비정상적으로 증가한 것이 확인되었습니다. 이후 환자는 단백질 제한 식이와 특수 분유 식이를 하루 4회 섭취하였고, 아르기닌과 나트륨 벤조산을 경구 투여받으면서 의식이 명료해져 내원 25일 후 퇴원하였습니다. H-H-H 증후군은 오르니틴 전달체의 결핍으로 인해 발생하는 드문 상염색체 열성 유전 질환으로, 요소 회로 장애를 초래합니다. 이 질환은 주로 단백질 섭취 후 증상이 나타나며, 고암모니아혈증과 혈중 오르니틴의 비정상적 증가가 특징입니다. 본 증례의 환자는 비교적 늦은 나이인 59세에 다량의 단백질 섭취 후 처음 증상이 발현되었으며, 혈중 오르니틴이 2배 정도 상승하였고, 호모시트룰린뇨가 관찰되었습니다. H-H-H 증후군 환자에서는 발달 장애, 지체 장애, 경련, 보행 장애, 응고 장애, 경직, 학습 장애, 구토, 단백질 불내성, 무기력 등의 증상이 나타날",
#   "_chunk_path": "/content/meta/TS국문학술 논문 및 저널/drive/cid_34873_1_0352_chunk_001.json",
#   "_done_path": "/content/meta/TS국문학술 논문 및 저널/drive/cid_34873_1_0352_chunk_001_done.json",
#   "keywords": [
#     "ornithine",
#     "homocysteine",
#     "ammonia",
#     "urea_cycle_disorder",
#     "h-h-h_syndrome",
#     "protein_intolerance",
#     "arginine",
#     "sodium_benzoate",
#     "antioxidant",
#     "cerebral_involvement"
#   ],
#   "procedure_type": [],
#   "target_area": [
#     "central_nervous_system",
#     "liver",
#     "gastrointestinal_tract"
#   ],
#   "symptoms": [
#     "altered_consciousness",
#     "seizures",
#     "motor_disability",
#     "ataxia",
#     "learning_disability",
#     "vomiting",
#     "proteins_intolerance",
#     "lethargy",
#     "hypotonia",
#     "coagulation_disorder"
#   ]
# }
# ================================================================================
# 파일 경로: /content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/meta/TS_국문의학 교과서/drive/cid_34873_1_0352_chunk_002_done.json
# {
#   "src_path": "/content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/TS_국문_학술 논문 및 저널/cid_34873_1_0352.json",
#   "ts_folder": "drive",
#   "file_name": "cid_34873_1_0352.json",
#   "base": "cid_34873_1_0352",
#   "chunk_id": 2,
#   "content": "관찰되었습니다. H-H-H 증후군 환자에서는 발달 장애, 지체 장애, 경련, 보행 장애, 응고 장애, 경직, 학습 장애, 구토, 단백질 불내성, 무기력 등의 증상이 나타날 수 있습니다. 고암모니아혈증은 신속히 치료하지 않으면 영구적인 뇌 손상을 초래할 수 있으므로, 응급실에서의 빠른 진단과 적극적인 처치가 요구됩니다. 특히 간 질환의 과거력이 없는 성인 환자가 갑작스러운 고암모니아혈증을 보일 경우, 대사 질환을 의심해야 하며, 관장 등의 처치에 반응하지 않는 경우 혈액 투석까지 고려해야 합니다.",
#   "_chunk_path": "/content/meta/TS국문학술 논문 및 저널/drive/cid_34873_1_0352_chunk_002.json",
#   "_done_path": "/content/meta/TS국문학술 논문 및 저널/drive/cid_34873_1_0352_chunk_002_done.json",
#   "keywords": [
#     "ammonia_metabolism",
#     "hyperammonemia",
#     "neurological_damage",
#     "metabolic_disorder",
#     "seizure",
#     "movement_disability",
#     "learning_disability",
#     "vomiting",
#     "protein_intolerance",
#     "coagulation_disorder"
#   ],
#   "procedure_type": [],
#   "target_area": [
#     "central_nervous_system"
#   ],
#   "symptoms": [
#     "seizure",
#     "motor_disability",
#     "gait_disability",
#     "learning_disability",
#     "vomiting",
#     "proteins_intolerance",
#     "lethargy",
#     "neurological_damage",
#     "coagulation_disorder"
#   ]
# }
# ================================================================================
# 파일 경로: /content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/meta/TS_국문의학 교과서/drive/cid_34883_1_chunk_000_done.json
# {
#   "src_path": "/content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/TS_국문_학술 논문 및 저널/cid_34883_1.json",
#   "ts_folder": "drive",
#   "file_name": "cid_34883_1.json",
#   "base": "cid_34883_1",
#   "chunk_id": 0,
#   "content": "S-100B 단백질은 중추신경계의 별아교세포와 말초신경계의 신경집 세포에 다량 포함된 21-kDa의 이량체 단백질로, 칼슘 결합 단백질군에 속합니다. 이 단백질은 뇌조직 특이성이 높아 두부손상 환자에서 중요한 생체표지자로 주목받고 있습니다. 1965년 Moore에 의해 처음 소의 뇌에서 분리되었으며, 100% 포화된 황산암모늄 용액에서 용해된다는 특성으로 인해 S-100이라는 이름이 붙여졌습니다. 이후 염색체 위치에 따라 S-100A1, S-100B, S-100P로 세분되었으며, 특히 뇌신경조직에 특이적인 S-100AB와 S-100BB를 S-100B로 정의합니다. 두부손상은 외상으로 인한 사망의 주요 원인 중 하나로, 응급센터를 찾는 환자들 중 약 80%는 경도 두부손상 환자입니다. 이들 대부분은 두개내 손상이 없는 경우가 많습니다. 두부손상 후 뇌조직은 일시적인 탈분극으로 인해 뇌부종이 발생하며, 저혈압, 저산소증, 출혈로 인한 빈혈 등의 이차적 손상이 동반될 수 있습니다. 따라서 두부외상 환자의 치료는 이차적 손상 예방에 초점이 맞춰져 있으며, 신속한 진단과 치료가 필수적입니다. 임상적으로 두부손상은 글라스고우혼수척도(GCS)에 따라 경도(GCS 14-15), 중등도(GCS 9-13), 중증(GCS 3-8)으로 분류됩니다. 경도 두부손상 환자는 위험인자에 따라 고위험군, 중등도 위험군, 저위험군으로 세분되며, 두개내 병변 확인을 위해 방사선학적 검사(단순 방사선촬영, 뇌전산화단층촬영, 뇌자기공명촬영 등)가 시행됩니다. S-100B 단백질 수치는 글라스고우혼수척도, 뇌부종, 뇌출혈 등 일차적 뇌손상의 정도와 비례한다는 보고가 있습니다. Korfias 등의 연구에 따르면, 중증 뇌손상 환자의 S-100B 단백질 수치는 환자의 동공 상태, 뇌전산화단층촬영 결과, 글라스고우혼수척도, 나이와 밀접한 상관관계를 보였습니다. 중등도 및 중증 두부손상 환자에서 뇌전산화단층촬영의 필요성은 명확하지만, 경도 두부손상 환자(GCS 14-15)에서의 뇌전산화단층촬영 시행 여부는",
#   "_chunk_path": "/content/meta/TS국문학술 논문 및 저널/drive/cid_34883_1_chunk_000.json",
#   "_done_path": "/content/meta/TS국문학술 논문 및 저널/drive/cid_34883_1_chunk_000_done.json",
#   "keywords": [
#     "s-100b",
#     "neuroglial_cell",
#     "cerebral_injury",
#     "gcs",
#     "brain_edema",
#     "secondary_injury",
#     "antioxidant",
#     "calcium_binding_protein"
#   ],
#   "procedure_type": [],
#   "target_area": [
#     "cerebral"
#   ],
#   "symptoms": [
#     "head_injury",
#     "brain_edema",
#     "hypotension",
#     "hypoxia",
#     "hemorrhage"
#   ]
# }
# ================================================================================
# 파일 경로: /content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/meta/TS_국문의학 교과서/drive/cid_34883_1_chunk_001_done.json
# {
#   "src_path": "/content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/TS_국문_학술 논문 및 저널/cid_34883_1.json",
#   "ts_folder": "drive",
#   "file_name": "cid_34883_1.json",
#   "base": "cid_34883_1",
#   "chunk_id": 1,
#   "content": "밀접한 상관관계를 보였습니다. 중등도 및 중증 두부손상 환자에서 뇌전산화단층촬영의 필요성은 명확하지만, 경도 두부손상 환자(GCS 14-15)에서의 뇌전산화단층촬영 시행 여부는 논란의 여지가 있습니다. 최근 연구들은 경도 두부손상 환자에서 뇌전산화단층촬영 시행 여부를 결정하기 위해 S-100B 단백질 값을 활용하려는 시도를 하고 있습니다. S-100B 단백질 값은 뇌손상을 놓치지 않으면서도 불필요한 뇌전산화단층촬영 빈도를 줄이는 데 기여할 수 있습니다. 이를 위해 두부손상 환자의 위험인자 평가가 중요합니다. 본 연구는 기존 연구를 바탕으로 고유의 위험인자를 제시하고, 경도 두부손상 환자에서 S-100B 단백질 값이 뇌전산화단층촬영 결과를 예측할 수 있는지 확인하고자 했습니다. 또한, 위험인자가 없고 S-100B 단백질 값이 정상인 환자에서 뇌전산화단층촬영 없이 응급실에서 퇴원할 수 있는지를 평가했습니다. 본 연구는 2007년 7월부터 9월까지 응급실에 내원한 경도 두부손상 환자 68명 중 50명을 대상으로 진행되었습니다. 환자들은 두통, 구토, 어지럼증, 의식소실, 외상 후 기억상실 등 임상 증상을 보였으며, S-100B 단백질 측정과 뇌전산화단층촬영을 시행했습니다. 위험인자는 나이(2세 이하 또는 60세 이상), 국소 신경학적 결손, 외상 후 경련, 두개골 골절, 두부외손상, 응고 장애 병력, 신경학적 결손 병력, 음주 및 약물 복용력 등 8가지로 설정되었습니다. 연구 결과, S-100B 단백질 값은 뇌전산화단층촬영 결과 이상 소견을 보인 환자에서 더 높게 나타났으나, 통계적 유의성은 부족했습니다. 그러나 위험인자가 없는 환자에서 S-100B 단백질 값이 정상 범위에 있는 경우, 뇌전산화단층촬영 없이도 안전하게 퇴원할 수 있을 가능성이 제시되었습니다. 이는 응급실에서 불필요한 뇌전산화단층촬영을 줄이고, 환자 관리의 효율성을 높이는 데 기여할 수 있습니다. 본 연구는 대상 환자 수가 적고 단일 기관에서 진행되었다는 한계가 있으나, 경도 두부손상 환자 평가에",
#   "_chunk_path": "/content/meta/TS국문학술 논문 및 저널/drive/cid_34883_1_chunk_001.json",
#   "_done_path": "/content/meta/TS국문학술 논문 및 저널/drive/cid_34883_1_chunk_001_done.json",
#   "keywords": [
#     "s-100b",
#     "gcs",
#     "cerebral_metabolism",
#     "head_injury",
#     "symptom",
#     "risk_factor"
#   ],
#   "procedure_type": [
#     "cerebral_metabolism_scan"
#   ],
#   "target_area": [
#     "cerebrum"
#   ],
#   "symptoms": [
#     "headache",
#     "vomiting",
#     "dizziness",
#     "altered_consciousness",
#     "post_traumatic_amnesia"
#   ]
# }
# ================================================================================
# 파일 경로: /content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/meta/TS_국문의학 교과서/drive/cid_34883_1_chunk_002_done.json
# {
#   "src_path": "/content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/TS_국문_학술 논문 및 저널/cid_34883_1.json",
#   "ts_folder": "drive",
#   "file_name": "cid_34883_1.json",
#   "base": "cid_34883_1",
#   "chunk_id": 2,
#   "content": "줄이고, 환자 관리의 효율성을 높이는 데 기여할 수 있습니다. 본 연구는 대상 환자 수가 적고 단일 기관에서 진행되었다는 한계가 있으나, 경도 두부손상 환자 평가에 있어 S-100B 단백질과 위험인자의 중요성을 강조하며, 향후 대규모 다기관 연구를 통해 추가 검증이 필요합니다.",
#   "_chunk_path": "/content/meta/TS국문학술 논문 및 저널/drive/cid_34883_1_chunk_002.json",
#   "_done_path": "/content/meta/TS국문학술 논문 및 저널/drive/cid_34883_1_chunk_002_done.json",
#   "keywords": [
#     "s100b",
#     "head_injury",
#     "risk_factor"
#   ],
#   "procedure_type": [],
#   "target_area": [
#     "cerebral"
#   ],
#   "symptoms": [
#     "head_injury"
#   ]
# }
# ================================================================================
# 파일 경로: /content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/meta/TS_국문의학 교과서/drive/cid_34886_1_0462_chunk_000_done.json
# {
#   "src_path": "/content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/TS_국문_학술 논문 및 저널/cid_34886_1_0462.json",
#   "ts_folder": "drive",
#   "file_name": "cid_34886_1_0462.json",
#   "base": "cid_34886_1_0462",
#   "chunk_id": 0,
#   "content": "초오는 미나리아재비과에 속하는 여러해살이 식물로, 덩이뿌리를 포함한 다양한 종이 있습니다. 초오는 그 형태가 까마귀의 머리와 비슷하다고 하여 '오두'라고도 불리며, 한의학에서는 약재로 사용하기 위해 가공 과정을 거칩니다. 이 과정에 따라 염부자, 담부자 등으로 나뉘어 불립니다. 초오에는 심장 독성을 유발하는 알칼로이드 성분이 포함되어 있으며, 서양에서는 주로 실험 동물에서 부정맥 유발 목적으로 사용됩니다. 반면, 한의학에서는 신진대사 항진, 항염증, 강심, 이뇨, 진통 등의 효능이 있다고 알려져 관절염, 신경통, 뇌혈관 질환 등에 사용됩니다. 그러나 초오의 낮은 치료역가와 독성으로 인해 부작용이 간과되기 쉽고, 민간에서 약효만 알려져 있어 오용 및 남용으로 인한 급성 중독 사례가 빈번히 보고되고 있습니다. 2006년 3월, 경기도 연천의 한 마을 부녀회 회원들이 강원도 관광 중 밀주를 마신 후 집단적으로 오심, 구토, 손발 마비, 흉부 불편감 등의 증상을 보여 병원에 내원했습니다. 밀주를 만든 과정에서 초오가 혼합된 것이 확인되었습니다. 밀주를 마신 21명 전원에게 증상이 발생했으며, 이 중 두 사례를 상세히 기술하였습니다. 첫 번째 사례는 66세 여성으로, 밀주를 한 모금 마신 후 1~2분 만에 구토와 전신 마비 증상이 나타났습니다. 과거 고혈압과 당뇨를 앓고 있었으며, 내원 당시 혈압이 낮아지고 심방세동과 비특이적 ST-T 분절 변화가 관찰되었습니다. 중환자실에서 치료 후 증상이 호전되어 퇴원하였습니다. 두 번째 사례는 50세 여성으로, 밀주를 한 모금 마신 후 20분 만에 오심, 구토, 전신 마비 증상이 나타났습니다. 과거 고혈압과 퇴행성 슬관절염으로 치료받은 병력이 있었습니다. 내원 당시 혈압이 낮아지고 심실 조기박동과 심비대 소견이 관찰되었습니다. 중환자실에서 치료 후 증상이 호전되어 퇴원하였습니다. 초오의 주요 독성 성분인 아코니틴은 신경, 심장, 근육 세포의 나트륨 채널에 작용하여 지속적인 탈분극 상태를 유발합니다. 이로 인해 구강 및 사지 마비,",
#   "_chunk_path": "/content/meta/TS국문학술 논문 및 저널/drive/cid_34886_1_0462_chunk_000.json",
#   "_done_path": "/content/meta/TS국문학술 논문 및 저널/drive/cid_34886_1_0462_chunk_000_done.json",
#   "keywords": [
#     "aconitine",
#     "alkaloid",
#     "antioxidant",
#     "cardiotonic",
#     "anti-inflammatory",
#     "diuretic",
#     "analgesic",
#     "gastrointestinal_distress",
#     "neurotoxin"
#   ],
#   "procedure_type": [],
#   "target_area": [
#     "central_nervous_system",
#     "cardiac_tissue",
#     "muscle_tissue"
#   ],
#   "symptoms": [
#     "vomiting",
#     "nausea",
#     "paralysis",
#     "hypotension",
#     "atrial_fibrillation",
#     "premature_ventricular_contraction",
#     "neurological_distress"
#   ]
# }
# ================================================================================
# 파일 경로: /content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/meta/TS_국문의학 교과서/drive/cid_34886_1_0462_chunk_001_done.json
# {
#   "src_path": "/content/drive/MyDrive/Colab Notebooks/LikeLion/실전 프로젝트 2/DATA/TS_국문_학술 논문 및 저널/cid_34886_1_0462.json",
#   "ts_folder": "drive",
#   "file_name": "cid_34886_1_0462.json",
#   "base": "cid_34886_1_0462",
#   "chunk_id": 1,
#   "content": "호전되어 퇴원하였습니다. 초오의 주요 독성 성분인 아코니틴은 신경, 심장, 근육 세포의 나트륨 채널에 작용하여 지속적인 탈분극 상태를 유발합니다. 이로 인해 구강 및 사지 마비, 전신 쇠약, 심혈관계 이상 등이 발생할 수 있습니다. 초오 중독은 경구 복용 후 빠르게 흡수되어 위장관 증상이 10분 이내에, 전신 증상이 2~6시간 내에 나타납니다. 본 사례에서는 밀주 형태로 복용하여 증상이 더 빠르게 나타난 것으로 보입니다. 초오 중독 치료에는 해독제가 없으므로, 약물의 신속한 배출과 쇼크 및 부정맥 교정 등 보존적 치료가 중요합니다. 본 사례에서는 위세척 및 활성탄 투여를 적절히 시행하지 못했으나, 대부분의 환자가 수액 및 혈압상승제 치료로 회복되었습니다. 부정맥 치료에는 리도카인, 아미오다론 등의 약물이 사용될 수 있으며, 심한 경우 심폐순환 보조 장치가 필요할 수 있습니다. 응급실에 내원하는 환자가 다양한 독성 증상을 보일 경우 초오 중독 가능성을 염두에 두어야 하며, 초오를 가공하지 않고 복용할 경우 중독 증상이 용량에 따라 발생할 수 있으므로 초기 응급 처치와 보존적 치료를 신속히 시행해야 합니다.",
#   "_chunk_path": "/content/meta/TS국문학술 논문 및 저널/drive/cid_34886_1_0462_chunk_001.json",
#   "_done_path": "/content/meta/TS국문학술 논문 및 저널/drive/cid_34886_1_0462_chunk_001_done.json",
#   "keywords": [
#     "aconitine",
#     "sodium_channel",
#     "antidote",
#     "fluid_resuscitation",
#     "antiventricular_therapy",
#     "lidocaine",
#     "amiodarone",
#     "activated_charcoal",
#     "hypotension",
#     "arrhythmia"
#   ],
#   "procedure_type": [],
#   "target_area": [
#     "nervous_system",
#     "cardiac_system",
#     "muscle_tissue"
#   ],
#   "symptoms": [
#     "oral_facial_paralysis",
#     "limb_paralysis",
#     "general_weakness",
#     "cardiovascular_disturbance",
#     "hypotension",
#     "arrhythmia"
#   ]
# }

# %% [markdown]
# # tmp

# %%
# import re

# @torch.inference_mode()
# def infer_chunks_to_done_files(chunk_store_dir: str, batch_size: int = 16):
#     chunk_files = list_all_chunk_files(chunk_store_dir)

#     ds = ChunkFileDataset(chunk_files)
#     dl = DataLoader(
#         ds,
#         batch_size=batch_size,
#         shuffle=False,
#         num_workers=0,          # 코랩 안정성
#         collate_fn=collate_keep_valid
#     )

#     model.eval()

#     processed = 0
#     skipped_batches = 0
#     parse_fail = 0
#     batch_errors = 0

#     for batch in tqdm(dl, desc="Pass B: 청크 배치 추론 -> done 저장"):
#         if len(batch) == 0:
#             skipped_batches += 1
#             continue

#         # 1) 프롬프트 구성
#         texts = []
#         for item in batch:
#             prompt_text = generate_prompt(item["content"])
#             messages = [{"role": "user", "content": prompt_text}]
#             text = tokenizer.apply_chat_template(
#                 messages,
#                 tokenize=False,
#                 add_generation_prompt=True,
#             )
#             texts.append(text)
#             # content만 추출

#         # 2) 배치 토크나이즈
#         model_inputs = tokenizer(
#             texts,
#             return_tensors="pt",
#             padding=True,
#             truncation=True,
#         ).to(model.device)


#         # 3) 배치 generate
#         generated_ids = model.generate(
#             **model_inputs,
#             max_new_tokens=MAX_NEW_TOKENS,
#             do_sample=False
#         )

#         # 4) 디코딩
#         decoded_texts = tokenizer.batch_decode(
#             generated_ids,
#             skip_special_tokens=True
#         )


#         # # 4) 샘플별 디코딩 (각 입력 길이만큼 잘라냄)
#         # input_lens = model_inputs["attention_mask"].sum(dim=1).tolist()

#         # for item, gen_ids, in_len in zip(batch, generated_ids, input_lens):
#         #     out_ids = gen_ids[int(in_len):].tolist()
#         #     generated_output = tokenizer.decode(out_ids, skip_special_tokens=True)

#         #     metadata = safe_json_loads(generated_output)
#         #     if metadata is None:
#         #         cleaned = re.sub(r'(?s).*?\bassistant\s*', '', generated_output)
#         #         metadata = safe_json_loads(cleaned)

#         #     if metadata is None:
#         #         parse_fail += 1
#         #         print(cleaned)
#         #         break

#         pattern = re.compile(r"\{[\s\S]*?\}") # 모든 딕셔너리 형태 잡기
#         for item, decoded_text in zip(batch, decoded_texts):
#             matches = list(pattern.finditer(decoded_text))

#             if len(matches) != 2:
#                 print(decoded_text)

#             json_candidate = matches[-1].group(0) if matches else None # 마지막것만
#             if json_candidate is None:
#                 print(decoded_text)
#                 print("----------------------------------------")

#             try:
#                 obj = json.loads(json_candidate)
#                 # 5) "청크 + 추론결과" 합쳐서 done 저장
#                 done_obj = {
#                     **item,                 # 원본 메타
#                     "chunk_id": item["chunk_id"],
#                     "content": item["content"],
#                     # 추론 결과를 합치는 부분 (원하던 구조)
#                     "keywords": obj.get("keywords", []),
#                     "procedure_type": obj.get("procedure_type", []),
#                     "target_area": obj.get("target_area", []),
#                     "symptoms": obj.get("symptoms", [])
#                 }

#                 with open(item["_done_path"], "w", encoding="utf-8") as f:
#                     json.dump(done_obj, f, ensure_ascii=False, indent=2)
#             except:
#                 print(decoded_text)

#             processed += 1




#     print("\n[Pass B]")
#     print("processed done chunks:", processed)
#     print("parse_fail chunks:", parse_fail)
#     print("batch_errors chunks:", batch_errors)
#     if skipped_batches:
#         print("skipped empty batches:", skipped_batches)

# # 실행
# infer_chunks_to_done_files(CHUNK_STORE_DIR, batch_size=30)

# %% [markdown]
# ## try

# %%
# import os
# import json
# import torch
# from torch.utils.data import DataLoader
# from tqdm import tqdm

# @torch.inference_mode()
# def infer_chunks_to_done_files(
#     chunk_store_dir: str,
#     batch_size: int = 8,
#     max_new_tokens: int = 256
# ):
#     chunk_files = list_all_chunk_files(chunk_store_dir)

#     ds = ChunkFileDataset(chunk_files)
#     dl = DataLoader(
#         ds,
#         batch_size=batch_size,
#         shuffle=False,
#         num_workers=0,          # Colab 안정성
#         collate_fn=collate_keep_valid
#     )

#     model.eval()

#     processed = 0

#     for batch in tqdm(dl, desc="Batch inference"):
#         if len(batch) == 0:
#             continue

#         texts = [generate_prompt(item["content"]) for item in batch]

#         inputs = tokenizer(
#             texts,
#             return_tensors="pt",
#             padding=True,
#             truncation=True
#         ).to(model.device)

#         generated_ids = model.generate(
#             **inputs,
#             max_new_tokens=max_new_tokens,
#             do_sample=False
#         )

#         decoded_texts = tokenizer.batch_decode(
#             generated_ids,
#             skip_special_tokens=True
#         )

#         for item, decoded in zip(batch, decoded_texts):
#             meta = safe_json_loads(decoded)

#             if meta is None:
#                 # JSON 파싱 실패 시 최소한의 구조라도 저장
#                 meta = {
#                     "keywords": [],
#                     "procedure_type": [],
#                     "target_area": [],
#                     "symptoms": []
#                 }

#             done_obj = {
#                 # --- chunk 기본 메타 ---
#                 "src_path": item.get("src_path", ""),
#                 "ts_folder": item.get("ts_folder", ""),
#                 "file_name": item.get("file_name", ""),
#                 "base": item.get("base", ""),
#                 "chunk_id": item.get("chunk_id"),
#                 "content": item.get("content", ""),

#                 # --- 의료 메타데이터 ---
#                 "keywords": meta.get("keywords", []),
#                 "procedure_type": meta.get("procedure_type", []),
#                 "target_area": meta.get("target_area", []),
#                 "symptoms": meta.get("symptoms", [])
#             }

#             with open(item["_done_path"], "w", encoding="utf-8") as f:
#                 json.dump(done_obj, f, ensure_ascii=False, indent=2)

#             processed += 1

#     print(f"총 처리 완료 chunk 수: {processed}")

# %%
# infer_chunks_to_done_files(CHUNK_STORE_DIR, batch_size=140)

# %%
# torch.cuda.empty_cache()
